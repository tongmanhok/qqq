# %% [markdown]
# ### Prepare dataframe
# 1- Read the csv file into a pandas dataframe. take a look at the header of this dataframe.

# %% [markdown]
# 2- Consider the first row as the header of the dataframe and country name as the index of the dataframe.

# %% [markdown]
# 3- Rename 01 to Gold, 02 to Silver, and 03 to Bronz.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('olympics.csv', skiprows = 1, index_col = 0)

# %%
data.head()
# Out:
#                          ? Summer  01 !  02 !  03 !  Total  ? Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
data.columns = ['Summer', 'Gold', 'Silver', 'Bronz', 'Summer_Total', 'Winter', 'Gold', 'Silver', 'Bronz', 'Winter_Total', 'Games', 'Gold', 'Silver', 'Bronz', 'Combined_Total']

# %%
data.head()
# Out:
#                          Summer  Gold  Silver  Bronz  Summer_Total  Winter  \
# Afghanistan (AFG)            13     0       0      2             2       0
# Algeria (ALG)                12     5       2      8            15       3
# Argentina (ARG)              23    18      24     28            70      18
# Armenia (ARM)                 5     1       2      9            12       6
# Australasia (ANZ) [ANZ]       2     3       4      5            12       0
#
#                          Gold  Silver  Bronz  Winter_Total  Games  Gold  \
# Afghanistan (AFG)           0       0      0             0     13     0
# Algeria (ALG)               0       0      0             0     15     5
# Argentina (ARG)             0       0      0             0     41    18
# Armenia (ARM)               0       0      0             0     11     1
# Australasia (ANZ) [ANZ]     0       0      0             0      2     3
#
#                          Silver  Bronz  Combined_Total
# ...

# %%
list(data.columns.values)
# Out:
# ['Summer',
#  'Gold',
#  'Silver',
#  'Bronz',
#  'Summer_Total',
#  'Winter',
#  'Gold',
#  'Silver',
#  'Bronz',
#  'Winter_Total',
#  'Games',
#  'Gold',
#  'Silver',
#  'Bronz',
#  'Combined_Total']

# %% [markdown]
# ### Querying a DataFrame
# 1- Find all countires won a good medal in summer olympic.

# %%
summer_gold = data[data.iloc[:,1] > 0]
summer_gold
# Out:
#                                      Summer  Gold  Silver  Bronz  \
# Algeria (ALG)                            12     5       2      8
# Argentina (ARG)                          23    18      24     28
# Armenia (ARM)                             5     1       2      9
# Australasia (ANZ) [ANZ]                   2     3       4      5
# Australia (AUS) [AUS] [Z]                25   139     152    177
# Austria (AUT)                            26    18      33     35
# Azerbaijan (AZE)                          5     6       5     15
# Bahamas (BAH)                            15     5       2      5
# Belarus (BLR)                             5    12      24     39
# Belgium (BEL)                            25    37      52     53
# Brazil (BRA)                             21    23      30     55
# Bulgaria (BUL) [H]                       19    51      85     78
# Burundi (BDI)                             5     1       0      0
# ...

# %%
list(summer_gold.index)
# Out:
# ['Algeria (ALG)',
#  'Argentina (ARG)',
#  'Armenia (ARM)',
#  'Australasia (ANZ) [ANZ]',
#  'Australia (AUS) [AUS] [Z]',
#  'Austria (AUT)',
#  'Azerbaijan (AZE)',
#  'Bahamas (BAH)',
#  'Belarus (BLR)',
#  'Belgium (BEL)',
#  'Brazil (BRA)',
#  'Bulgaria (BUL) [H]',
#  'Burundi (BDI)',
#  'Cameroon (CMR)',
#  'Canada (CAN)',
#  'Chile (CHI) [I]',
#  'China (CHN) [CHN]',
#  'Colombia (COL)',
#  'Costa Rica (CRC)',
#  'Croatia (CRO)',
#  'Cuba (CUB) [Z]',
#  'Czech Republic (CZE) [CZE]',
#  'Czechoslovakia (TCH) [TCH]',
#  'Denmark (DEN) [Z]',
#  'Dominican Republic (DOM)',
#  'Ecuador (ECU)',
#  'Egypt (EGY) [EGY] [Z]',
#  'Estonia (EST)',
#  'Ethiopia (ETH)',
#  'Finland (FIN)',
#  'France (FRA) [O] [P] [Z]',
#  'Georgia (GEO)',
#  'Germany (GER) [GER] [Z]',
#  'United Team of Germany (EUA) [EUA]',
#  'East Germany (GDR) [GDR]',
#  'West Germany (FRG) [FRG]',
#  'Great Britain (GBR) [GBR] [Z]',
#  'Greece (GRE) [Z]',
#  'Grenada (GRN)',
#  'Hong Kong (HKG) [HKG]',
# ...

# %% [markdown]
# 2 - How many countries did win a gold medal in summer olympics?

# %%
print(len(summer_gold.index))
# Out:
# 100

# %% [markdown]
# 3- Create a dataframe of all countires with atleast one gold medal in summer olympic.

# %%
summer_gold
# Out:
#                                      Summer  Gold  Silver  Bronz  \
# Algeria (ALG)                            12     5       2      8
# Argentina (ARG)                          23    18      24     28
# Armenia (ARM)                             5     1       2      9
# Australasia (ANZ) [ANZ]                   2     3       4      5
# Australia (AUS) [AUS] [Z]                25   139     152    177
# Austria (AUT)                            26    18      33     35
# Azerbaijan (AZE)                          5     6       5     15
# Bahamas (BAH)                            15     5       2      5
# Belarus (BLR)                             5    12      24     39
# Belgium (BEL)                            25    37      52     53
# Brazil (BRA)                             21    23      30     55
# Bulgaria (BUL) [H]                       19    51      85     78
# Burundi (BDI)                             5     1       0      0
# ...

# %% [markdown]
# 4- Create a dataframe of all countries with atleast one gold medal either in summer or winter olympic.

# %%
winter_gold = data[data.iloc[:,7] > 0]
one_gold = pd.concat([summer_gold,winter_gold]).drop_duplicates()
one_gold
# Out:
#                                   index  Summer  Gold  Silver  Bronz  \
# 0                         Algeria (ALG)      12     5       2      8
# 1                       Argentina (ARG)      23    18      24     28
# 2                         Armenia (ARM)       5     1       2      9
# 3               Australasia (ANZ) [ANZ]       2     3       4      5
# 4             Australia (AUS) [AUS] [Z]      25   139     152    177
# 5                         Austria (AUT)      26    18      33     35
# 6                      Azerbaijan (AZE)       5     6       5     15
# 7                         Bahamas (BAH)      15     5       2      5
# 8                         Belarus (BLR)       5    12      24     39
# 9                         Belgium (BEL)      25    37      52     53
# 10                         Brazil (BRA)      21    23      30     55
# 11                   Bulgaria (BUL) [H]      19    51      85     78
# 12                        Burundi (BDI)       5     1       0      0
# ...

# %%
o_gold = data.loc[(data.iloc[:,7] > 0) | (data.iloc[:,1] > 0)]
o_gold
# Out:
#                                      Summer  Gold  Silver  Bronz  \
# Algeria (ALG)                            12     5       2      8
# Argentina (ARG)                          23    18      24     28
# Armenia (ARM)                             5     1       2      9
# Australasia (ANZ) [ANZ]                   2     3       4      5
# Australia (AUS) [AUS] [Z]                25   139     152    177
# Austria (AUT)                            26    18      33     35
# Azerbaijan (AZE)                          5     6       5     15
# Bahamas (BAH)                            15     5       2      5
# Belarus (BLR)                             5    12      24     39
# Belgium (BEL)                            25    37      52     53
# Brazil (BRA)                             21    23      30     55
# Bulgaria (BUL) [H]                       19    51      85     78
# Burundi (BDI)                             5     1       0      0
# ...

# %% [markdown]
# 5- Find the list of countries won gold medals only in the winter olympic and not in summer olympic.

# %%
winter_only = data.loc[(data.iloc[:,7] > 0 ) & (data.iloc[:,1] == 0)]
list(winter_only.index)
# Out:
# ['Liechtenstein (LIE)']
